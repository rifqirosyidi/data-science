# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1. Sample Plot with 4 data**

# %%
plt.plot([1, 3, 2, 4])
plt.show()

# %% [markdown]
# #### **Test Plot**

# %%
plt.plot([1, 2, 3, 4], [1, 9, 10, 18])
plt.title("TEST PLOT", pad=15, fontsize=14, color='red')
plt.xlabel("First Arr")
plt.ylabel("Second Arr")
plt.show()

# %% [markdown]
# #### **N Pangkat**

# %%
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.title("N PANGKAT", pad=15, fontsize=14, color='red')
plt.xlabel("n")
plt.ylabel("n^2")
plt.show()

# %% [markdown]
# ### **2. Change The Size**

# %% [markdown]
# ##### **X wide = 2; Y wide = 5**

# %% [markdown]
# ##### **with X axis = 0-5; Y axis = 0-20**

# %%
plt.figure(figsize=(2,5))
plt.plot([1,2,3,4], [1,4,9,16], 'bx')  # red=r; black=x; circle=o; cross=x; 
plt.axis([0, 6, 0, 20])  # Axis [xstart, xend, ystart, yend]
plt.annotate("cool right", (3,7))
plt.show()

# %% [markdown]
# ### **3. Bar Chart**

# %%
plt.clf() # Clear Figure
x = np.arange(6)
y = np.random.randint(1, 10, 6)
plt.xticks(x, ('Data A', 'Data B', 'Data C', 'Data D', 'Data E', 'Data F'))
plt.bar(x, y, color=['g', 'y'])  # color : y, k, b, r, lime, tan *** OR *** color [t, r, b] this will give different color
plt.show()

# %% [markdown]
# ### **4. Random Dots**

# %%
data = {
    'Blue O': np.random.rand(10),
    'Red X': np.random.rand(10)
}

data_frame = pd.DataFrame(data)
print(data_frame)

data_frame.plot()

data_frame.plot(style=['bo', 'rx'])

plt.show()
# Out:
#      Blue O     Red X
# 0  0.061766  0.361344
# 1  0.376392  0.215639
# 2  0.379311  0.149337
# 3  0.967438  0.858305
# 4  0.362499  0.200548
# 5  0.963471  0.746392
# 6  0.425428  0.302703
# 7  0.277830  0.269670
# 8  0.541082  0.715641
# 9  0.495035  0.538548

# %% [markdown]
# ### **4. Time Series**

# %%
time_stamp = pd.Series(np.random.randn(180), index=pd.date_range('1/1/2019', periods=180))
data_frame = pd.DataFrame(np.random.randn(180,3), index=time_stamp.index, columns=['A','B','C'])  # or columns=list(ABC) > same

print(data_frame)
data_frame.cumsum()

data_frame.cumsum().plot()
plt.show()
# Out:
#                    A         B         C
# 2019-01-01  1.546897  0.810171 -0.745776
# 2019-01-02  1.330033 -1.008513 -1.417212
# 2019-01-03 -1.758957 -0.336818  1.135437
# 2019-01-04 -1.483296  1.450582  0.239043
# 2019-01-05  0.124990  0.733401 -0.868953
# ...              ...       ...       ...
# 2019-06-25  1.023566  0.693763  1.433573
# 2019-06-26 -0.155820 -0.806825 -0.430220
# 2019-06-27  0.198653  0.148430 -0.046876
# 2019-06-28 -0.036597 -0.556792  3.236902
# 2019-06-29  0.578754  0.851641 -2.226117
#
# [180 rows x 3 columns]
